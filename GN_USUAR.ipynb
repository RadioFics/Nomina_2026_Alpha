-- %% [markdown]
-- # [dbo].[GN_USUAR]

-- %%
USE [MineDax]
GO

-- %%
/****** Object:  Table [dbo].[GN_USUAR]    Script Date: 14/04/2026 3:13:33 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GN_USUAR](
	[COD_EMPR] [smallint] NOT NULL,
	[COD_USUA] [bigint] IDENTITY(1,1) NOT NULL,
	[COD_FUNCI] [int] NULL,
	[NOM_USUA] [char](240) NOT NULL,
	[ABR_USUA] [char](8) NULL,
	[TIP_USUA] [char](1) NULL,
	[PAS_USUA] [char](16) NULL,
	[FEC_ACTI] [datetime] NULL,
	[FEC_EXPI] [datetime] NULL,
	[COD_GUSU] [bigint] NULL,
	[VER_ACTU] [char](1) NULL,
	[CAM_PASS] [char](1) NULL,
	[FEC_ULCA] [datetime] NULL,
	[NRO_DICP] [int] NULL,
	[ACT_INAC] [char](1) NULL,
	[FEC_ULEN] [datetime] NULL,
	[DIR_ELEC] [char](100) NULL,
	[NUM_CONE] [smallint] NULL,
	[DES_BLOQ] [varchar](50) NULL,
	[NUM_INTF] [smallint] NULL,
	[EVA_SESI] [varchar](40) NULL,
	[COD_PERF] [smallint] NULL,
	[USU_LARG] [varchar](100) NULL,
	[USU_TWEB] [char](1) NULL,
	[IMG_FIRM] [image] NULL,
	[OBL_CPAS] [char](1) NULL,
	[SEL_PVTA] [char](1) NULL,
	[USU_TMOV] [char](1) NULL,
	[ID] [char](8) NULL,
	[ACT_USUA] [char](8) NOT NULL,
	[ACT_HORA] [datetime] NOT NULL,
	[ACT_ESTA] [char](1) NOT NULL,
	[PAS_HASH] [varchar](255) NULL,
	[INT_FALL] [smallint] NULL,
	[IND_BLOQ] [char](1) NULL,
	[FEC_PRCA] [datetime] NULL,
	[TOK_RECO] [varchar](100) NULL,
	[FEC_TOKE] [datetime] NULL,
 CONSTRAINT [PK_GN_USUAR] PRIMARY KEY CLUSTERED 
(
	[COD_EMPR] ASC,
	[COD_USUA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %%
SET IDENTITY_INSERT [dbo].[GN_USUAR] ON 
INSERT [dbo].[GN_USUAR] ([COD_EMPR], [COD_USUA], [COD_FUNCI], [NOM_USUA], [ABR_USUA], [TIP_USUA], [PAS_USUA], [FEC_ACTI], [FEC_EXPI], [COD_GUSU], [VER_ACTU], [CAM_PASS], [FEC_ULCA], [NRO_DICP], [ACT_INAC], [FEC_ULEN], [DIR_ELEC], [NUM_CONE], [DES_BLOQ], [NUM_INTF], [EVA_SESI], [COD_PERF], [USU_LARG], [USU_TWEB], [IMG_FIRM], [OBL_CPAS], [SEL_PVTA], [USU_TMOV], [ID], [ACT_USUA], [ACT_HORA], [ACT_ESTA], [PAS_HASH], [INT_FALL], [IND_BLOQ], [FEC_PRCA], [TOK_RECO], [FEC_TOKE]) VALUES (1, 1, NULL, N'Gestion TIC                                                                                                                                                                                                                                     ', N'TIC     ', N'D', N'Gestic2198#$    ', CAST(N'2024-01-19T08:19:37.067' AS DateTime), CAST(N'2026-04-07T00:00:00.000' AS DateTime), 18, N'N', N'S', CAST(N'2026-03-24T12:13:12.587' AS DateTime), 360, N'A', CAST(N'2024-01-19T08:19:37.067' AS DateTime), N'gestiontic@ingetierras.com                                                                          ', 0, NULL, 0, NULL, 1, N'GESTION TIC', N'N', NULL, N'N', N'S', N'N', N'dcarvaja', N'dcarvaja', CAST(N'2024-01-19T00:00:00.000' AS DateTime), N'M', NULL, NULL, NULL, NULL, NULL, NULL)
INSERT [dbo].[GN_USUAR] ([COD_EMPR], [COD_USUA], [COD_FUNCI], [NOM_USUA], [ABR_USUA], [TIP_USUA], [PAS_USUA], [FEC_ACTI], [FEC_EXPI], [COD_GUSU], [VER_ACTU], [CAM_PASS], [FEC_ULCA], [NRO_DICP], [ACT_INAC], [FEC_ULEN], [DIR_ELEC], [NUM_CONE], [DES_BLOQ], [NUM_INTF], [EVA_SESI], [COD_PERF], [USU_LARG], [USU_TWEB], [IMG_FIRM], [OBL_CPAS], [SEL_PVTA], [USU_TMOV], [ID], [ACT_USUA], [ACT_HORA], [ACT_ESTA], [PAS_HASH], [INT_FALL], [IND_BLOQ], [FEC_PRCA], [TOK_RECO], [FEC_TOKE]) VALUES (1, 2, NULL, N'Nomina                                                                                                                                                                                                                                          ', N'Nomina  ', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, N'MineDax ', CAST(N'2026-03-31T13:45:12.550' AS DateTime), N'A', NULL, NULL, NULL, NULL, NULL, NULL)
INSERT [dbo].[GN_USUAR] ([COD_EMPR], [COD_USUA], [COD_FUNCI], [NOM_USUA], [ABR_USUA], [TIP_USUA], [PAS_USUA], [FEC_ACTI], [FEC_EXPI], [COD_GUSU], [VER_ACTU], [CAM_PASS], [FEC_ULCA], [NRO_DICP], [ACT_INAC], [FEC_ULEN], [DIR_ELEC], [NUM_CONE], [DES_BLOQ], [NUM_INTF], [EVA_SESI], [COD_PERF], [USU_LARG], [USU_TWEB], [IMG_FIRM], [OBL_CPAS], [SEL_PVTA], [USU_TMOV], [ID], [ACT_USUA], [ACT_HORA], [ACT_ESTA], [PAS_HASH], [INT_FALL], [IND_BLOQ], [FEC_PRCA], [TOK_RECO], [FEC_TOKE]) VALUES (1, 3, NULL, N'laura.calle                                                                                                                                                                                                                                     ', N'RRHH    ', NULL, N'laura@ffd.n*    ', NULL, NULL, 5, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, N'MineDax ', CAST(N'2026-03-31T13:46:51.537' AS DateTime), N'A', NULL, NULL, NULL, NULL, NULL, NULL)
INSERT [dbo].[GN_USUAR] ([COD_EMPR], [COD_USUA], [COD_FUNCI], [NOM_USUA], [ABR_USUA], [TIP_USUA], [PAS_USUA], [FEC_ACTI], [FEC_EXPI], [COD_GUSU], [VER_ACTU], [CAM_PASS], [FEC_ULCA], [NRO_DICP], [ACT_INAC], [FEC_ULEN], [DIR_ELEC], [NUM_CONE], [DES_BLOQ], [NUM_INTF], [EVA_SESI], [COD_PERF], [USU_LARG], [USU_TWEB], [IMG_FIRM], [OBL_CPAS], [SEL_PVTA], [USU_TMOV], [ID], [ACT_USUA], [ACT_HORA], [ACT_ESTA], [PAS_HASH], [INT_FALL], [IND_BLOQ], [FEC_PRCA], [TOK_RECO], [FEC_TOKE]) VALUES (1, 4, 1, N'HERNANDEZ LARGO JUAN FELIPE                                                                                                                                                                                                                     ', N'HL      ', N'E', N'11111111        ', CAST(N'2026-04-13T15:13:46.463' AS DateTime), CAST(N'2026-07-12T15:13:46.463' AS DateTime), NULL, NULL, N'S', CAST(N'2026-04-13T15:13:46.463' AS DateTime), 90, N'A', NULL, N'hernandezjuanfelipe964@gmail.com                                                                    ', 0, NULL, 0, NULL, 100, N'HERNANDEZ LARGO JUAN FELIPE', N'S', NULL, N'S', NULL, N'S', NULL, N'TIC     ', CAST(N'2026-04-13T15:13:46.463' AS DateTime), N'A', N'$2b$12$abcdefghijklmnopqrst...', 0, N'N', CAST(N'2026-07-12T15:13:46.463' AS DateTime), NULL, NULL)
INSERT [dbo].[GN_USUAR] ([COD_EMPR], [COD_USUA], [COD_FUNCI], [NOM_USUA], [ABR_USUA], [TIP_USUA], [PAS_USUA], [FEC_ACTI], [FEC_EXPI], [COD_GUSU], [VER_ACTU], [CAM_PASS], [FEC_ULCA], [NRO_DICP], [ACT_INAC], [FEC_ULEN], [DIR_ELEC], [NUM_CONE], [DES_BLOQ], [NUM_INTF], [EVA_SESI], [COD_PERF], [USU_LARG], [USU_TWEB], [IMG_FIRM], [OBL_CPAS], [SEL_PVTA], [USU_TMOV], [ID], [ACT_USUA], [ACT_HORA], [ACT_ESTA], [PAS_HASH], [INT_FALL], [IND_BLOQ], [FEC_PRCA], [TOK_RECO], [FEC_TOKE]) VALUES (1, 6, 7, N'CALLE PALMETT JUAN ESTEBAN                                                                                                                                                                                                                      ', NULL, NULL, NULL, NULL, NULL, 2, NULL, NULL, CAST(N'2026-04-14T15:08:32.457' AS DateTime), NULL, N'S', NULL, N'juane.calle@upb.edu.co                                                                              ', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, N'SISTEMA ', CAST(N'2026-04-14T15:08:32.457' AS DateTime), N'A', N'$2a$10$r5PfTigc9NCM6EMH442lnevN8J7.6cQfShDDZY.vkb188gTYBFWsm', 0, N'N', NULL, NULL, NULL)
SET IDENTITY_INSERT [dbo].[GN_USUAR] OFF
GO

-- %% [markdown]
-- # [DF_GN_USUAR_COD_EMPR]

-- %%
ALTER TABLE [dbo].[GN_USUAR] ADD  CONSTRAINT [DF_GN_USUAR_COD_EMPR]  DEFAULT ((1)) FOR [COD_EMPR]
GO

-- %% [markdown]
-- # [DF_GN_USUAR_COD_TERC]

-- %%
ALTER TABLE [dbo].[GN_USUAR] ADD  CONSTRAINT [DF_GN_USUAR_COD_TERC]  DEFAULT ((0)) FOR [COD_FUNCI]
GO

-- %% [markdown]
-- # [DF_GN_USUAR_ACT_USUA]

-- %%
ALTER TABLE [dbo].[GN_USUAR] ADD  CONSTRAINT [DF_GN_USUAR_ACT_USUA]  DEFAULT ('MineDax') FOR [ACT_USUA]
GO

-- %% [markdown]
-- # [DF_GN_USUAR_ACT_HORA]

-- %%
ALTER TABLE [dbo].[GN_USUAR] ADD  CONSTRAINT [DF_GN_USUAR_ACT_HORA]  DEFAULT (getdate()) FOR [ACT_HORA]
GO

-- %% [markdown]
-- # [DF_GN_USUAR_ACT_ESTA]

-- %%
ALTER TABLE [dbo].[GN_USUAR] ADD  CONSTRAINT [DF_GN_USUAR_ACT_ESTA]  DEFAULT ('A') FOR [ACT_ESTA]
GO

-- %% [markdown]
-- # [DF__GN_USUAR__INT_FA__2B9540A9]

-- %%
ALTER TABLE [dbo].[GN_USUAR] ADD  CONSTRAINT [DF__GN_USUAR__INT_FA__2B9540A9]  DEFAULT ((0)) FOR [INT_FALL]
GO

-- %% [markdown]
-- # [DF__GN_USUAR__IND_BL__2C8964E2]

-- %%
ALTER TABLE [dbo].[GN_USUAR] ADD  CONSTRAINT [DF__GN_USUAR__IND_BL__2C8964E2]  DEFAULT ('N') FOR [IND_BLOQ]
GO

-- %% [markdown]
-- # [FK_GN_USUAR_GN_FUNCI]

-- %%
ALTER TABLE [dbo].[GN_USUAR]  WITH CHECK ADD  CONSTRAINT [FK_GN_USUAR_GN_FUNCI] FOREIGN KEY([COD_FUNCI])
REFERENCES [dbo].[GN_FUNCI] ([COD_FUNCI])
GO
ALTER TABLE [dbo].[GN_USUAR] CHECK CONSTRAINT [FK_GN_USUAR_GN_FUNCI]
GO
